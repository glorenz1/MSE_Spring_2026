# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/MSE_Spring_2026/blob/main/Module%204/20_NeuralODE_system_identification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Notebook for MSE 510/420 Spring 2026
# - Neural differential equations
# - Blog:https://medium.com/towards-data-science/modeling-dynamical-systems-with-neural-ode-a-hands-on-guide-71c4cfdb84dc
# - Code: https://github.com/ShuaiGuo16/neuralODE
# - Refactored by Sergei V. Kalinin (comment - training unstable)

# %%
# Re-import necessary libraries since execution state was reset
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Define the ODE function
def ode_func(t, y):
    return 2 * y

# Define initial conditions and time span
y_init_vals = np.linspace(-2, 2, 20)  # Initial conditions for vector field
t_vals = np.linspace(0, 2, 10)   # Time values for vector field
t_span = (0, 2)
t_eval = np.linspace(0, 2, 100)

# Solve ODE for specific initial conditions
sol1 = solve_ivp(ode_func, t_span, [0.5], t_eval=t_eval)  # y0 = 0.5
sol2 = solve_ivp(ode_func, t_span, [-0.7], t_eval=t_eval)  # y0 = -0.7

# Create meshgrid for the vector field
T, Y = np.meshgrid(t_vals, y_init_vals)
dY = 2 * Y  # Compute derivatives
dT = np.ones_like(dY)  # Time derivative is always 1

# Normalize the vector field for better visualization
magnitude = np.sqrt(dT**2 + dY**2)
dT /= magnitude
dY /= magnitude

# Plot the vector field
plt.figure(figsize=(8, 6))
plt.quiver(T, Y, dT, dY, color="blue", alpha=0.6, label="Vector Field")

# Plot the solution trajectories
plt.plot(sol1.t, sol1.y[0], 'r-', linewidth=2, label="y0 = 0.5")
plt.plot(sol2.t, sol2.y[0], 'r--', linewidth=2, label="y0 = -0.7")

# Labels, title, and legend
plt.xlabel("Time (t)")
plt.ylabel("y")
plt.title("Vector Field with Solution Trajectories for ODE: y' = 2y")
plt.legend()
plt.grid()

# Ensure range is within initial conditions
plt.ylim(y_init_vals.min(), y_init_vals.max())

plt.show()

# %%
# !pip install torchdiffeq
# Out:
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from torchdiffeq) (2.10.0+cu128)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from torchdiffeq) (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy>=1.4.0->torchdiffeq) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torchdiffeq) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.5.0->torchdiffeq) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.5.0->torchdiffeq) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.5.0->torchdiffeq) (3.0.3)
# Downloading torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# Installing collected packages: torchdiffeq
# Successfully installed torchdiffeq-0.2.5

# %%
import torch
import torchdiffeq

# Define a simple neural ODE system
class ODEFunc(torch.nn.Module):
    def __init__(self):
        super(ODEFunc, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 50),
            torch.nn.Tanh(),
            torch.nn.Linear(50, 2)
        )

    def forward(self, t, x):
        return self.net(x)

# Define initial condition and solver
func = ODEFunc()
x0 = torch.tensor([[1.0, 0.0]], requires_grad=True)
t = torch.linspace(0, 2, 100)

# Solve forward
xT = torchdiffeq.odeint(func, x0, t)

# Compute loss
loss = torch.sum(xT)

# Compute gradients using the adjoint method
loss.backward()

# Get gradients
gradients = x0.grad
print(gradients)
# Out:
# tensor([[77.8187, 85.0268]])

# %%
# Define a different forward ODE: y' = -y (exponential decay)
def forward_ode(t, y):
    return -y  # Leads to solutions that decay instead of diverging

# Define the adjoint ODE: a' = -a (same form, but for gradient tracking)
def adjoint_ode(t, a):
    return -a

# Define time span and evaluation points
t_span = (0, 2)
t_eval = np.linspace(0, 2, 100)

# Solve forward ODE for y0 = 1
sol_forward = solve_ivp(forward_ode, t_span, [1.0], t_eval=t_eval)

# Solve adjoint ODE backward in time
sol_adjoint = solve_ivp(adjoint_ode, (2, 0), [0.1], t_eval=t_eval[::-1])  # Reverse time

# Define vector field grid
t_vals = np.linspace(0, 2, 10)
y_vals = np.linspace(-2, 2, 20)
T, Y = np.meshgrid(t_vals, y_vals)
dY = -Y  # Forward field (exponential decay)
dT = np.ones_like(dY)

# Normalize for visualization
magnitude = np.sqrt(dT**2 + dY**2)
dT /= magnitude
dY /= magnitude

# Plot forward pass
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

ax[0].quiver(T, Y, dT, dY, color="blue", alpha=0.6)
ax[0].plot(sol_forward.t, sol_forward.y[0], 'r-', linewidth=2, label="Forward Pass (y)")
ax[0].set_title("Forward ODE: y' = -y (Exponential Decay)")
ax[0].set_xlabel("Time (t)")
ax[0].set_ylabel("y")
ax[0].legend()
ax[0].grid()

# Plot backward pass
ax[1].quiver(T, Y, -dT, -dY, color="purple", alpha=0.6)  # Reverse field for adjoint
ax[1].plot(sol_adjoint.t, sol_adjoint.y[0], 'g-', linewidth=2, label="Adjoint Pass (a)")
ax[1].set_title("Adjoint ODE: a' = -a (Gradient Tracking)")
ax[1].set_xlabel("Time (t)")
ax[1].set_ylabel("a (gradient)")
ax[1].legend()
ax[1].grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Objective
#
# In this notebook, we implement the **Neural ODE** approach to model a dynamical system described by the *ordinary differential equation* (ODE).

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk", font_scale=0.7)

import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(42)

from scipy.integrate import solve_ivp
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ### 1. Target Dynamical System: Logistic Growth Model
#
# In this notebook, we investigate a specific dynamical system called [logistic growth system](https://services.math.duke.edu/education/ccp/materials/diffeq/logistic/logi1.html). This system is widely used in biology and ecology for modeling animal population growth under limited resources:
#
# \begin{equation}
# \frac{dp(t)}{dt} = rp(t)(1-\frac{p(t)}{k}) - H(p(t)).
# \end{equation}
#
# Here, $p(t)$ denotes the population size at time $t$, $r$ and $k$ represent the intrinsic growth rate of the population and carrying capacity of the environment, respectively.
#
# $H(\cdot)$ is a harvesting function and reflects the removal of the animal population due to harvesting (or culling). In the current study, we adopt the following expression for $H(\cdot)$:
#
# \begin{equation}
# H(p(t)) = min(h \cdot p, H_{max}),
# \end{equation}
#
# where harvesting is proportional to the population size (harvesting rate $h$), but is capped at a maximum value $H_{max}$, for the purpose of sustainable management.

# %%
def logistic_growth(t, p, r, k, h, H_max):
    """
    ODE for logistic growth model.

    Inputs:
    -------
    t: time
    p: population size
    r: intrinsic growth rate
    k: carrying capacity
    h: harvesting rate
    H_max: maximum harvesting capacity

    Output:
    -------
    dpdt: Change rate of population size.
    """

    dpdt = r*p*(1-p/k) - min(h*p, H_max)

    return dpdt

# %% [markdown]
# ### 2. Case Study: Dynamic Discovery
#
# In this section, we tackle the first case study, i.e., dynamic discovery.
#
# Here, we assume that while the harvesting function is known (controlled by human activity), the exact functional form that governs the *natural dynamics* of the population evolution remains unknown:
#
# \begin{equation}
# \frac{dp}{dt} = f_{unknown}(p) - min(h \cdot p, H_{max}).
# \end{equation}
#
# This case study has practical meaning as for real-world complex dynamica systems, it is often challenging to derive an explicit expression to describe the system dynamics. However, with the Neural ODE approach, we can potentially infer this underlying functional form from observational data.

# %% [markdown]
# #### 2.1 Strategy
#
# The key idea of identifying hidden dynamics in Neural ODE is to approximate the unknown function $f_{unknown}(p)$ with a neural network:
#
# \begin{equation}
# \frac{dp}{dt} = f_{NN}(p) - min(h \cdot p, H_{max}).
# \end{equation}
#
# By training the $f_{NN}(p)$ based on the observation data of $p$, we are able to obtain a predictive model that takes in the population size p, and outputs the population change induced by the natural dynamics, thus completing the ODE.

# %% [markdown]
# Since we can only observe the population size $p$ and not its derivative $dp/dt$, we need to find a way to approximate those derivatives to facilitate training. Fortunately, traditional numerical methods for solving ODE has provided us with a range of techniques to discretize the derivatives. In this study, we opt for a simple Euler scheme to approximate the $dp/dt$ term:
#
# \begin{equation}
# \frac{dp}{dt} = \frac{p_{i+1}-p_{i}}{\Delta t},
# \end{equation}
#
# where $p_{i}$ and $p_{i+1}$ indicate the population size at the current and subsequent time steps, respectively, and $\Delta t$ denotes the time interval between these steps. We can then substitute this discretized version of $dp/dt$ back into the ODE:
#
# \begin{equation}
# \frac{p_{i+1}-p_{i}}{\Delta t} = f_{NN}(p_{i}) - min(h \cdot p_{i}, H_{max}).
# \end{equation}

# %% [markdown]
# #### 2.2 Data Generation
#
# To begin with, let's generate the observation data required for training the Neural ODE model. Toward that end, we assign a specific set of values to the ODE parameters and leverage the scipy ODE solver to simulate the corresponding dynamical system for a given timespan. This obtained time trace will serve as our training dataset.
#
# Note that here the true ODE model is used only for creating the observation data. Later, we will assume that we have no access to the complete  form of the underlying ODE, and instead train a neural network model to infer the unknown dynamics based on the observation data.

# %%
# Set parameters
r, k, h, H_max = 0.1, 1000, 0.01, 5

# Initial condition
p_0 = 20

# Simulation time span
t_span = (0, 100)
t_eval = np.linspace(t_span[0], t_span[1], 10000)

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0],
                     t_eval=t_eval, args=(r, k, h, H_max))

# %% [markdown]
# Here, we visualize the general trend of the population evolution given the set ODE parameters.

# %%
plt.plot(solution.t, solution.y[0])
plt.xlabel('Time (days)')
plt.ylabel('Population Size')
plt.title('Logistic Growth Model')
plt.show()

# %% [markdown]
# #### 2.3 Data organization
#
# Next, we organize the obtained dataset into a proper format suitable for model training. There are several practical considerations worth discussing when preparing the dataset:
#
# 1. **windowing**: The entire dataset contains one time series of 100 days in real-time. Instead of overwhelming the model by feeding the entire time series, we could instead divide the full dataset into smaller chunks of continuous data samples. By processing shorter sequences at a time, we made it easier for the model to capture the complex dynamics, we greatly increased the diversity of the training data (e.g., every segment of time serie starts with a different initial condition), thus promoting the generalization capability of the model, as well as reducing the memory and computational resources for training.
#
# 2. **Overlapping**: To ensure continuity in the data, we allow adjacent windows to share a portion of data, i.e., the end of one window overlaps with the beginning of the next. This practice helps the model to maintain context across window boundaries, and effectively augment the dataset as each data point is used in multiple windows but with different contexts.
#
# 3. **Multi-Step Ahead Prediction**: To be practically useful, the model should be able to perform long-term forecasting. In practice, this is usually achieved in an autoregressive manner, i.e., the model uses its prediction at the current time step as inputs and predicts for the next time step. As a result, our training procedure should also align with such scenarios: during training, instead of using the actual observed values for each subsequent prediction step, the model uses its previous prediction as the input for the next prediction. This way improves the model's predictive accuracy and robustness for long-term forecasting tasks.

# %%
def create_windows(p_series, t_series, seq_length, overlap_length):
    """
    Create windows from the given time series data.
    Overlapping is introduced to ensure context continuity.

    Inputs:
    -------
    p_series: time series of observed population size
    t_series: observed time
    seq_length: intrinsic growth rate
    overlap_length: carrying capacity

    Output:
    -------
    p_windows: segmented window array of population size
    t_windows: segmented window array of the time
    """

    p_windows, t_windows = [], []

    step_size = seq_length - overlap_length
    beg_index = 0

    while (end_idx := beg_index + seq_length) <= len(p_series):

        # Construct P array
        p_windows.append(p_series[beg_index:end_idx])

        # Calculate time intervals
        time_intervals = t_series[beg_index:end_idx] - t_series[beg_index]
        t_windows.append(time_intervals)

        beg_index += step_size

    return np.array(p_windows), np.array(t_windows)

# %%
# Compile dataset
p_windows, t_windows = create_windows(solution.y[0][:, np.newaxis], t_eval, seq_length=20, overlap_length=10)
print(f"p_windows array dimension: {p_windows.shape}")
# Out:
# p_windows array dimension: (999, 20, 1)

# %%
# Create TensorFlow Dataset
p_windows = p_windows.astype('float32')
t_windows = t_windows.astype('float32')

batch_size = 128
dataset = tf.data.Dataset.from_tensor_slices((p_windows, t_windows))

# %% [markdown]
# We split the entire dataset into a train set and a validation set. This validation set can be used to monitor the learning progress of the model and facilitate learning rate scheduling.
#
# Toward that end, we can randomly shuffle the dataset first and then select the first 80% for training and the remaining 20% for validation. It is worth mentioning that this way of splitting the dataset actually does not violate the temporal order: the shuffling operation only acts on the first dimension of `p_windows`, i.e., it rearranges these windows as complete units. Since each window still preserves its original temporal sequence, the overall temporal consistency of the data is not violated.

# %%
# Train/validation split
split_ratio = 0.8
train_num = int(split_ratio*len(p_windows))

# Split the dataset
dataset = dataset.shuffle(buffer_size=100000)
train_dataset = dataset.take(train_num)
val_dataset = dataset.skip(train_num)

# Batch the train & val datasets
train_dataset = train_dataset.batch(batch_size).shuffle(buffer_size=100000)
val_dataset = val_dataset.batch(batch_size)

# %% [markdown]
# ### 3. Neural ODE Solution

# %% [markdown]
# #### 3.1 Define the neural network model
#
# Here, we use a standard feed-forward neural network to represent $f_{NN}(\cdot)$. This network takes a scalar value $p(t)$ (the population size at time $t$) as input and outputs a scalar value that denotes the population change rate induced by the natural dynamics (see ODE above).
#
# To compute the final population change rate (induced by both natural dynamics and harvesting function), we define a custom layer to perform the calculation.

# %%
class PopulationChangeLayer(tf.keras.layers.Layer):
    def __init__(self, h, H_max, **kwargs):
        """
        Constructor for the custom layer for computing the population change rate.

        Inputs:
        -------
        h: harvesting rate
        H_max: maximum harvesting capacity
        """
        super(PopulationChangeLayer, self).__init__(**kwargs)
        self.h = h
        self.H_max = H_max

    def call(self, inputs, natural_dynamcis, *args, **kwargs):
        """
        This layer takes the results of natural dynamics and adds the effect of harvesting.

        Inputs:
        -------
        inputs: population size
        natural_dynamcis: population change rate induced by natural dynamics
        """

        # The governing ODE
        dp_dt = natural_dynamcis - tf.minimum(self.h*inputs, self.H_max)

        return dp_dt

# %%
def define_model(input_dim, hidden_dims, output_dim, init_lr, h, H_max):
    """
    Construct a standard feed-forward NN for Neural ODE.

    Inputs:
    -------
    input_dim: input dimension
    hidden_dims: list, dimensions for hidden layers
    output_dim: output dimension
    init_lr: initial learning rate
    h: harvesting rate
    H_max: maximum harvesting capacity

    Outputs:
    --------
    model: the compiled neural network model
    """

    # Input layer
    input_layer = keras.layers.Input(shape=(input_dim,))

    # Hidden layers
    for i, neuron_num in enumerate(hidden_dims):
        if i == 0:
            hidden = keras.layers.Dense(neuron_num, activation="selu", kernel_initializer='LecunNormal')(input_layer)

        else:
            hidden = keras.layers.Dense(neuron_num, activation="selu", kernel_initializer='LecunNormal')(hidden)

    # Population change rate induced by natural dynamics
    natural_dynamics = keras.layers.Dense(output_dim, activation="linear")(hidden)

    # Total population change rate
    dp_dt = PopulationChangeLayer(h, H_max)(input_layer, natural_dynamics)

    # Compile model
    model = tf.keras.models.Model(inputs=input_layer, outputs=[dp_dt, natural_dynamics])
    optimizer=tf.keras.optimizers.Adam(learning_rate=init_lr)
    model.compile(optimizer=optimizer)

    return model

# %% [markdown]
# #### 3.2 Define loss function
#
# Here, we define a custom loss function to facilitate neural ODE training. Specifically, we implement the logic of multi-step ahead prediction to improve the model's accuracy and robustness for performing long-term forecasting.

# %%
@tf.function
def train_step(p_batch, t_batch, ode_nn):
    """Calculate loss and its gradients with respect to network model parameters.

    Inputs:
    ----
    p_batch: a batch of population evolution data, [batch_size, timesteps, feature_dim]
    t_batch: a batch of time evolution data, [batch_size, timesteps, feature_dim]
    ode_nn: neural ODE model

    Outputs:
    --------
    ODE_loss: calculated ODE loss
    gradients: gradients of the ODE loss with respect to network model parameters.
    """

    with tf.GradientTape() as tape:
        batch_size, seq_length, _ = p_batch.shape
        loss = 0

        # Batch processing each step of the time series
        p = p_batch[:, 0]
        for i in range(seq_length - 1):

            # Calculate time step
            delta_t = t_batch[:, i+1] - t_batch[:, i]

            # Calculate the population change rate
            dp_dt, _ = ode_nn(p)

            # Euler scheme
            p = p + delta_t[:, tf.newaxis]*dp_dt

            # Sum loss for the whole batch (for the current time step)
            loss += tf.reduce_mean(tf.square(p - p_batch[:, i+1]))

        # Average the loss over all time steps
        loss /= (seq_length - 1)

    # Compute gradients
    gradients = tape.gradient(loss, ode_nn.trainable_variables)

    return loss, gradients

# %%
def val_step(p_batch, t_batch, ode_nn):
    """Calculate validation loss.

    Inputs:
    ----
    p_batch: a batch of population evolution data, [batch_size, timesteps, feature_dim]
    t_batch: a batch of time evolution data, [batch_size, timesteps, feature_dim]
    ode_nn: neural ODE model

    Outputs:
    --------
    loss: calculated ODE loss
    """
    batch_size, seq_length, _ = p_batch.shape
    loss = 0

    # Batch processing each step of the time series
    p = p_batch[:, 0]
    for i in range(seq_length - 1):

        # Calculate time step
        delta_t = t_batch[:, i+1] - t_batch[:, i]

        # Calculate the population change rate
        dp_dt, _ = ode_nn(p)

        # Euler scheme
        p = p + delta_t[:, tf.newaxis]*dp_dt

        # Sum loss for the whole batch (for the current time step)
        loss += tf.reduce_mean(tf.square(p - p_batch[:, i+1]))

    # Average the loss over all time steps
    loss /= (seq_length - 1)

    return loss

# %% [markdown]
# #### 3.3 Training logic

# %%
# Setup NN hyperparameters
input_dim, output_dim = 1, 1
hidden_dims = [5, 5, 5]

# Instantiate NN
ode_nn = define_model(input_dim, hidden_dims, output_dim, init_lr=1e-2, h=h, H_max=H_max)

# Training Loop
num_epochs = 600
train_loss_hist, val_loss_hist = [], []

with tf.device("CPU:0"):

    # Configure learning rate scheduler
    ode_nn_callbacks = tf.keras.callbacks.CallbackList(
                      [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=50)],
                        add_history=False, model=ode_nn)

    for epoch in range(num_epochs):

        # Initialize epoch-wise losses
        train_total_loss, val_total_loss = 0, 0

        # Training
        for p_batch, t_batch in train_dataset:

            # Calculate loss & gradients
            train_loss, gradients = train_step(p_batch, t_batch, ode_nn)

            # Update parameters
            ode_nn.optimizer.apply_gradients(zip(gradients, ode_nn.trainable_variables))

            # Accumulate loss
            train_total_loss += train_loss

        # Normalize loss
        train_total_loss /= len(train_dataset)

        # Validation loop
        for p_batch, t_batch in val_dataset:
            val_loss = val_step(p_batch, t_batch, ode_nn)
            val_total_loss += val_loss

        # Normalize validation loss
        val_total_loss /= len(val_dataset)

        # Callbacks
        ode_nn_callbacks.on_epoch_end(epoch, logs={'val_loss': val_total_loss})

        # Logging
        print(f"Epoch {epoch+1}:")
        print(f"Train Loss: {train_total_loss.numpy():.3e}, Val Loss: {val_total_loss.numpy():.3e}")
        #print(f"lr: {ode_nn.optimizer.lr.numpy():.3e}")

        train_loss_hist.append(train_total_loss)
        val_loss_hist.append(val_total_loss)

        # Reshuffle train dataset
        dataset = dataset.shuffle(buffer_size=100000)
        train_dataset = dataset.take(train_num).shuffle(buffer_size=100000).batch(batch_size)
        val_dataset = dataset.skip(train_num).batch(batch_size)
# Out:
# Epoch 1:
# Train Loss: 7.502e+01, Val Loss: 7.912e+00
# Epoch 2:
# Train Loss: 4.150e+00, Val Loss: 2.488e+00
# Epoch 3:
# Train Loss: 2.677e+00, Val Loss: 2.375e+00
# Epoch 4:
# Train Loss: 2.303e+00, Val Loss: 2.000e+00
# Epoch 5:
# Train Loss: 2.207e+00, Val Loss: 2.060e+00
# Epoch 6:
# Train Loss: 1.996e+00, Val Loss: 2.045e+00
# Epoch 7:
# Train Loss: 1.864e+00, Val Loss: 1.842e+00
# Epoch 8:
# Train Loss: 1.802e+00, Val Loss: 1.673e+00
# Epoch 9:
# Train Loss: 1.723e+00, Val Loss: 1.968e+00
# Epoch 10:
# Train Loss: 1.823e+00, Val Loss: 1.805e+00
# Epoch 11:
# Train Loss: 1.788e+00, Val Loss: 1.906e+00
# Epoch 12:
# Train Loss: 1.767e+00, Val Loss: 1.522e+00
# Epoch 13:
# Train Loss: 1.667e+00, Val Loss: 1.714e+00
# Epoch 14:
# Train Loss: 1.656e+00, Val Loss: 1.556e+00
# Epoch 15:
# Train Loss: 1.618e+00, Val Loss: 1.641e+00
# Epoch 16:
# Train Loss: 1.551e+00, Val Loss: 1.687e+00
# Epoch 17:
# Train Loss: 1.549e+00, Val Loss: 1.673e+00
# Epoch 18:
# Train Loss: 1.557e+00, Val Loss: 1.319e+00
# Epoch 19:
# Train Loss: 1.503e+00, Val Loss: 1.494e+00
# Epoch 20:
# Train Loss: 1.527e+00, Val Loss: 1.558e+00
# Epoch 21:
# Train Loss: 1.409e+00, Val Loss: 1.075e+00
# Epoch 22:
# Train Loss: 1.339e+00, Val Loss: 1.388e+00
# Epoch 23:
# Train Loss: 1.404e+00, Val Loss: 9.928e-01
# Epoch 24:
# Train Loss: 1.318e+00, Val Loss: 1.240e+00
# Epoch 25:
# Train Loss: 1.391e+00, Val Loss: 1.257e+00
# Epoch 26:
# Train Loss: 1.332e+00, Val Loss: 1.174e+00
# Epoch 27:
# Train Loss: 1.269e+00, Val Loss: 1.237e+00
# Epoch 28:
# Train Loss: 1.251e+00, Val Loss: 1.177e+00
# Epoch 29:
# Train Loss: 1.237e+00, Val Loss: 1.350e+00
# Epoch 30:
# Train Loss: 1.229e+00, Val Loss: 1.131e+00
# Epoch 31:
# Train Loss: 1.201e+00, Val Loss: 1.201e+00
# Epoch 32:
# Train Loss: 1.170e+00, Val Loss: 1.087e+00
# Epoch 33:
# Train Loss: 1.099e+00, Val Loss: 9.980e-01
# Epoch 34:
# Train Loss: 1.103e+00, Val Loss: 1.101e+00
# Epoch 35:
# Train Loss: 1.117e+00, Val Loss: 1.022e+00
# Epoch 36:
# Train Loss: 9.885e-01, Val Loss: 1.012e+00
# Epoch 37:
# Train Loss: 1.056e+00, Val Loss: 1.186e+00
# Epoch 38:
# Train Loss: 1.003e+00, Val Loss: 9.428e-01
# Epoch 39:
# Train Loss: 1.023e+00, Val Loss: 1.070e+00
# Epoch 40:
# Train Loss: 9.588e-01, Val Loss: 9.755e-01
# Epoch 41:
# Train Loss: 9.773e-01, Val Loss: 9.590e-01
# Epoch 42:
# Train Loss: 9.626e-01, Val Loss: 9.027e-01
# Epoch 43:
# Train Loss: 9.046e-01, Val Loss: 9.294e-01
# Epoch 44:
# Train Loss: 9.037e-01, Val Loss: 8.532e-01
# Epoch 45:
# Train Loss: 9.370e-01, Val Loss: 8.690e-01
# Epoch 46:
# Train Loss: 8.669e-01, Val Loss: 8.301e-01
# Epoch 47:
# Train Loss: 8.208e-01, Val Loss: 9.253e-01
# Epoch 48:
# Train Loss: 8.327e-01, Val Loss: 8.656e-01
# Epoch 49:
# Train Loss: 8.255e-01, Val Loss: 8.052e-01
# Epoch 50:
# Train Loss: 7.860e-01, Val Loss: 8.224e-01
# Epoch 51:
# Train Loss: 8.541e-01, Val Loss: 7.576e-01
# Epoch 52:
# Train Loss: 7.907e-01, Val Loss: 7.749e-01
# Epoch 53:
# Train Loss: 8.004e-01, Val Loss: 9.024e-01
# Epoch 54:
# Train Loss: 7.471e-01, Val Loss: 6.893e-01
# Epoch 55:
# Train Loss: 7.564e-01, Val Loss: 6.588e-01
# Epoch 56:
# Train Loss: 7.618e-01, Val Loss: 7.429e-01
# Epoch 57:
# Train Loss: 7.208e-01, Val Loss: 7.306e-01
# Epoch 58:
# Train Loss: 6.967e-01, Val Loss: 8.874e-01
# Epoch 59:
# Train Loss: 6.907e-01, Val Loss: 7.526e-01
# Epoch 60:
# Train Loss: 6.987e-01, Val Loss: 6.887e-01
# Epoch 61:
# Train Loss: 7.059e-01, Val Loss: 7.568e-01
# Epoch 62:
# Train Loss: 6.661e-01, Val Loss: 7.491e-01
# Epoch 63:
# Train Loss: 6.403e-01, Val Loss: 6.339e-01
# Epoch 64:
# Train Loss: 6.677e-01, Val Loss: 5.708e-01
# Epoch 65:
# Train Loss: 6.211e-01, Val Loss: 7.119e-01
# Epoch 66:
# Train Loss: 6.639e-01, Val Loss: 6.150e-01
# Epoch 67:
# Train Loss: 6.147e-01, Val Loss: 6.474e-01
# Epoch 68:
# Train Loss: 6.232e-01, Val Loss: 6.322e-01
# Epoch 69:
# Train Loss: 6.266e-01, Val Loss: 5.802e-01
# Epoch 70:
# Train Loss: 5.852e-01, Val Loss: 5.476e-01
# Epoch 71:
# Train Loss: 5.983e-01, Val Loss: 5.644e-01
# Epoch 72:
# Train Loss: 6.189e-01, Val Loss: 6.212e-01
# Epoch 73:
# Train Loss: 5.948e-01, Val Loss: 5.787e-01
# Epoch 74:
# Train Loss: 5.952e-01, Val Loss: 5.464e-01
# Epoch 75:
# Train Loss: 5.935e-01, Val Loss: 5.708e-01
# Epoch 76:
# Train Loss: 5.669e-01, Val Loss: 5.593e-01
# Epoch 77:
# Train Loss: 5.377e-01, Val Loss: 5.671e-01
# Epoch 78:
# Train Loss: 5.955e-01, Val Loss: 6.318e-01
# Epoch 79:
# Train Loss: 5.808e-01, Val Loss: 6.194e-01
# Epoch 80:
# Train Loss: 5.456e-01, Val Loss: 6.017e-01
# Epoch 81:
# Train Loss: 5.806e-01, Val Loss: 5.879e-01
# Epoch 82:
# Train Loss: 5.181e-01, Val Loss: 5.389e-01
# Epoch 83:
# Train Loss: 5.048e-01, Val Loss: 5.709e-01
# Epoch 84:
# Train Loss: 5.203e-01, Val Loss: 5.120e-01
# Epoch 85:
# Train Loss: 5.240e-01, Val Loss: 5.456e-01
# Epoch 86:
# Train Loss: 5.111e-01, Val Loss: 5.268e-01
# Epoch 87:
# Train Loss: 5.491e-01, Val Loss: 5.396e-01
# Epoch 88:
# Train Loss: 5.084e-01, Val Loss: 5.389e-01
# Epoch 89:
# Train Loss: 5.192e-01, Val Loss: 4.628e-01
# Epoch 90:
# Train Loss: 5.328e-01, Val Loss: 4.975e-01
# Epoch 91:
# Train Loss: 5.068e-01, Val Loss: 4.682e-01
# Epoch 92:
# Train Loss: 5.004e-01, Val Loss: 4.820e-01
# Epoch 93:
# Train Loss: 5.004e-01, Val Loss: 5.051e-01
# Epoch 94:
# Train Loss: 4.945e-01, Val Loss: 5.500e-01
# Epoch 95:
# Train Loss: 5.278e-01, Val Loss: 4.616e-01
# Epoch 96:
# Train Loss: 5.035e-01, Val Loss: 5.029e-01
# Epoch 97:
# Train Loss: 5.215e-01, Val Loss: 5.217e-01
# Epoch 98:
# Train Loss: 5.095e-01, Val Loss: 5.115e-01
# Epoch 99:
# Train Loss: 4.948e-01, Val Loss: 4.806e-01
# Epoch 100:
# Train Loss: 5.127e-01, Val Loss: 4.658e-01
# Epoch 101:
# Train Loss: 4.908e-01, Val Loss: 4.410e-01
# Epoch 102:
# Train Loss: 4.947e-01, Val Loss: 5.002e-01
# Epoch 103:
# Train Loss: 4.631e-01, Val Loss: 4.945e-01
# Epoch 104:
# Train Loss: 4.952e-01, Val Loss: 4.347e-01
# Epoch 105:
# Train Loss: 4.841e-01, Val Loss: 4.556e-01
# Epoch 106:
# Train Loss: 4.865e-01, Val Loss: 4.464e-01
# Epoch 107:
# Train Loss: 4.897e-01, Val Loss: 5.098e-01
# Epoch 108:
# Train Loss: 5.074e-01, Val Loss: 5.062e-01
# Epoch 109:
# Train Loss: 4.699e-01, Val Loss: 5.027e-01
# Epoch 110:
# Train Loss: 4.936e-01, Val Loss: 4.365e-01
# Epoch 111:
# Train Loss: 4.621e-01, Val Loss: 5.047e-01
# Epoch 112:
# Train Loss: 4.918e-01, Val Loss: 5.127e-01
# Epoch 113:
# Train Loss: 4.871e-01, Val Loss: 4.017e-01
# Epoch 114:
# Train Loss: 4.704e-01, Val Loss: 5.203e-01
# Epoch 115:
# Train Loss: 4.797e-01, Val Loss: 4.849e-01
# Epoch 116:
# Train Loss: 4.637e-01, Val Loss: 4.357e-01
# Epoch 117:
# Train Loss: 4.886e-01, Val Loss: 4.469e-01
# Epoch 118:
# Train Loss: 4.722e-01, Val Loss: 5.007e-01
# Epoch 119:
# Train Loss: 4.529e-01, Val Loss: 4.934e-01
# Epoch 120:
# Train Loss: 4.690e-01, Val Loss: 4.380e-01
# Epoch 121:
# Train Loss: 4.385e-01, Val Loss: 4.669e-01
# Epoch 122:
# Train Loss: 4.748e-01, Val Loss: 5.299e-01
# Epoch 123:
# Train Loss: 4.773e-01, Val Loss: 4.902e-01
# Epoch 124:
# Train Loss: 4.617e-01, Val Loss: 4.657e-01
# Epoch 125:
# Train Loss: 4.607e-01, Val Loss: 4.139e-01
# Epoch 126:
# Train Loss: 4.857e-01, Val Loss: 4.987e-01
# Epoch 127:
# Train Loss: 4.890e-01, Val Loss: 4.710e-01
# Epoch 128:
# Train Loss: 4.656e-01, Val Loss: 4.866e-01
# Epoch 129:
# Train Loss: 4.801e-01, Val Loss: 4.426e-01
# Epoch 130:
# Train Loss: 4.671e-01, Val Loss: 4.788e-01
# Epoch 131:
# Train Loss: 4.692e-01, Val Loss: 5.012e-01
# Epoch 132:
# Train Loss: 4.556e-01, Val Loss: 4.385e-01
# Epoch 133:
# Train Loss: 4.616e-01, Val Loss: 4.821e-01
# Epoch 134:
# Train Loss: 4.662e-01, Val Loss: 4.265e-01
# Epoch 135:
# Train Loss: 4.825e-01, Val Loss: 4.429e-01
# Epoch 136:
# Train Loss: 4.790e-01, Val Loss: 4.069e-01
# Epoch 137:
# Train Loss: 4.823e-01, Val Loss: 4.695e-01
# Epoch 138:
# Train Loss: 4.549e-01, Val Loss: 5.196e-01
# Epoch 139:
# Train Loss: 4.416e-01, Val Loss: 4.878e-01
# Epoch 140:
# Train Loss: 4.501e-01, Val Loss: 3.931e-01
# Epoch 141:
# Train Loss: 4.619e-01, Val Loss: 4.707e-01
# Epoch 142:
# Train Loss: 4.565e-01, Val Loss: 4.159e-01
# Epoch 143:
# Train Loss: 4.684e-01, Val Loss: 4.669e-01
# Epoch 144:
# Train Loss: 4.498e-01, Val Loss: 4.204e-01
# Epoch 145:
# Train Loss: 4.606e-01, Val Loss: 4.968e-01
# Epoch 146:
# Train Loss: 4.811e-01, Val Loss: 4.744e-01
# Epoch 147:
# Train Loss: 4.735e-01, Val Loss: 4.663e-01
# Epoch 148:
# Train Loss: 4.513e-01, Val Loss: 4.897e-01
# Epoch 149:
# Train Loss: 4.674e-01, Val Loss: 4.817e-01
# Epoch 150:
# Train Loss: 4.647e-01, Val Loss: 5.131e-01
# Epoch 151:
# Train Loss: 4.828e-01, Val Loss: 4.746e-01
# Epoch 152:
# Train Loss: 4.629e-01, Val Loss: 4.207e-01
# Epoch 153:
# Train Loss: 4.524e-01, Val Loss: 4.858e-01
# Epoch 154:
# Train Loss: 4.724e-01, Val Loss: 4.761e-01
# Epoch 155:
# Train Loss: 4.697e-01, Val Loss: 4.482e-01
# Epoch 156:
# Train Loss: 4.513e-01, Val Loss: 4.785e-01
# Epoch 157:
# Train Loss: 4.718e-01, Val Loss: 4.279e-01
# Epoch 158:
# Train Loss: 4.586e-01, Val Loss: 4.772e-01
# Epoch 159:
# Train Loss: 4.665e-01, Val Loss: 4.620e-01
# Epoch 160:
# Train Loss: 4.648e-01, Val Loss: 5.186e-01
# Epoch 161:
# Train Loss: 4.543e-01, Val Loss: 4.482e-01
# Epoch 162:
# Train Loss: 4.737e-01, Val Loss: 4.898e-01
# Epoch 163:
# Train Loss: 4.728e-01, Val Loss: 4.456e-01
# Epoch 164:
# Train Loss: 4.764e-01, Val Loss: 5.092e-01
# Epoch 165:
# Train Loss: 4.737e-01, Val Loss: 4.048e-01
# Epoch 166:
# Train Loss: 4.679e-01, Val Loss: 5.253e-01
# Epoch 167:
# Train Loss: 4.857e-01, Val Loss: 4.452e-01
# Epoch 168:
# Train Loss: 4.591e-01, Val Loss: 5.119e-01
# Epoch 169:
# Train Loss: 4.808e-01, Val Loss: 4.507e-01
# Epoch 170:
# Train Loss: 4.663e-01, Val Loss: 4.492e-01
# Epoch 171:
# Train Loss: 4.628e-01, Val Loss: 4.888e-01
# Epoch 172:
# Train Loss: 4.587e-01, Val Loss: 5.118e-01
# Epoch 173:
# Train Loss: 4.626e-01, Val Loss: 4.721e-01
# Epoch 174:
# Train Loss: 4.764e-01, Val Loss: 4.343e-01
# Epoch 175:
# Train Loss: 4.631e-01, Val Loss: 4.232e-01
# Epoch 176:
# Train Loss: 4.654e-01, Val Loss: 4.798e-01
# Epoch 177:
# Train Loss: 4.697e-01, Val Loss: 4.498e-01
# Epoch 178:
# Train Loss: 4.697e-01, Val Loss: 4.467e-01
# Epoch 179:
# Train Loss: 4.663e-01, Val Loss: 5.080e-01
# Epoch 180:
# Train Loss: 4.649e-01, Val Loss: 4.783e-01
# Epoch 181:
# Train Loss: 4.573e-01, Val Loss: 5.034e-01
# Epoch 182:
# Train Loss: 4.791e-01, Val Loss: 4.793e-01
# Epoch 183:
# Train Loss: 4.698e-01, Val Loss: 4.623e-01
# Epoch 184:
# Train Loss: 4.588e-01, Val Loss: 4.773e-01
# Epoch 185:
# Train Loss: 4.528e-01, Val Loss: 4.557e-01
# Epoch 186:
# Train Loss: 4.574e-01, Val Loss: 4.547e-01
# Epoch 187:
# Train Loss: 4.461e-01, Val Loss: 4.344e-01
# Epoch 188:
# Train Loss: 4.625e-01, Val Loss: 4.888e-01
# Epoch 189:
# Train Loss: 4.481e-01, Val Loss: 4.355e-01
# Epoch 190:
# Train Loss: 4.758e-01, Val Loss: 4.629e-01
# Epoch 191:
# Train Loss: 4.584e-01, Val Loss: 4.477e-01
# Epoch 192:
# Train Loss: 4.505e-01, Val Loss: 5.113e-01
# Epoch 193:
# Train Loss: 4.656e-01, Val Loss: 4.112e-01
# Epoch 194:
# Train Loss: 4.582e-01, Val Loss: 4.524e-01
# Epoch 195:
# Train Loss: 4.646e-01, Val Loss: 4.550e-01
# Epoch 196:
# Train Loss: 4.560e-01, Val Loss: 4.546e-01
# Epoch 197:
# Train Loss: 4.892e-01, Val Loss: 4.379e-01
# Epoch 198:
# Train Loss: 4.511e-01, Val Loss: 4.825e-01
# Epoch 199:
# Train Loss: 4.604e-01, Val Loss: 4.666e-01
# Epoch 200:
# Train Loss: 4.635e-01, Val Loss: 4.406e-01
# Epoch 201:
# Train Loss: 4.580e-01, Val Loss: 4.282e-01
# Epoch 202:
# Train Loss: 4.532e-01, Val Loss: 4.886e-01
# Epoch 203:
# Train Loss: 4.779e-01, Val Loss: 4.488e-01
# Epoch 204:
# Train Loss: 4.576e-01, Val Loss: 4.859e-01
# Epoch 205:
# Train Loss: 4.586e-01, Val Loss: 4.880e-01
# Epoch 206:
# Train Loss: 4.655e-01, Val Loss: 5.063e-01
# Epoch 207:
# Train Loss: 4.623e-01, Val Loss: 4.647e-01
# Epoch 208:
# Train Loss: 4.645e-01, Val Loss: 5.062e-01
# Epoch 209:
# Train Loss: 4.657e-01, Val Loss: 5.007e-01
# Epoch 210:
# Train Loss: 4.672e-01, Val Loss: 5.079e-01
# Epoch 211:
# Train Loss: 4.614e-01, Val Loss: 4.314e-01
# Epoch 212:
# Train Loss: 4.660e-01, Val Loss: 5.075e-01
# Epoch 213:
# Train Loss: 4.625e-01, Val Loss: 4.520e-01
# Epoch 214:
# Train Loss: 4.596e-01, Val Loss: 4.604e-01
# Epoch 215:
# Train Loss: 4.737e-01, Val Loss: 4.767e-01
# Epoch 216:
# Train Loss: 4.623e-01, Val Loss: 4.489e-01
# Epoch 217:
# Train Loss: 4.693e-01, Val Loss: 4.849e-01
# Epoch 218:
# Train Loss: 4.637e-01, Val Loss: 4.814e-01
# Epoch 219:
# Train Loss: 4.806e-01, Val Loss: 4.215e-01
# Epoch 220:
# Train Loss: 4.608e-01, Val Loss: 4.677e-01
# Epoch 221:
# Train Loss: 4.614e-01, Val Loss: 4.462e-01
# Epoch 222:
# Train Loss: 4.783e-01, Val Loss: 4.869e-01
# Epoch 223:
# Train Loss: 4.845e-01, Val Loss: 4.502e-01
# Epoch 224:
# Train Loss: 4.778e-01, Val Loss: 4.478e-01
# Epoch 225:
# Train Loss: 4.598e-01, Val Loss: 4.666e-01
# Epoch 226:
# Train Loss: 4.510e-01, Val Loss: 4.287e-01
# Epoch 227:
# Train Loss: 4.614e-01, Val Loss: 4.837e-01
# Epoch 228:
# Train Loss: 4.506e-01, Val Loss: 4.796e-01
# Epoch 229:
# Train Loss: 4.603e-01, Val Loss: 4.417e-01
# Epoch 230:
# Train Loss: 4.671e-01, Val Loss: 5.091e-01
# Epoch 231:
# Train Loss: 4.745e-01, Val Loss: 4.821e-01
# Epoch 232:
# Train Loss: 4.681e-01, Val Loss: 4.431e-01
# Epoch 233:
# Train Loss: 4.798e-01, Val Loss: 4.472e-01
# Epoch 234:
# Train Loss: 4.609e-01, Val Loss: 4.292e-01
# Epoch 235:
# Train Loss: 4.773e-01, Val Loss: 4.720e-01
# Epoch 236:
# Train Loss: 4.584e-01, Val Loss: 4.053e-01
# Epoch 237:
# Train Loss: 4.613e-01, Val Loss: 4.843e-01
# Epoch 238:
# Train Loss: 4.542e-01, Val Loss: 4.427e-01
# Epoch 239:
# Train Loss: 4.513e-01, Val Loss: 4.827e-01
# Epoch 240:
# Train Loss: 4.608e-01, Val Loss: 4.743e-01
# Epoch 241:
# Train Loss: 4.592e-01, Val Loss: 5.248e-01
# Epoch 242:
# Train Loss: 4.709e-01, Val Loss: 4.438e-01
# Epoch 243:
# Train Loss: 4.681e-01, Val Loss: 4.194e-01
# Epoch 244:
# Train Loss: 4.732e-01, Val Loss: 5.020e-01
# Epoch 245:
# Train Loss: 4.577e-01, Val Loss: 4.188e-01
# Epoch 246:
# Train Loss: 4.641e-01, Val Loss: 4.563e-01
# Epoch 247:
# Train Loss: 4.623e-01, Val Loss: 4.412e-01
# Epoch 248:
# Train Loss: 4.479e-01, Val Loss: 4.972e-01
# Epoch 249:
# Train Loss: 4.877e-01, Val Loss: 4.068e-01
# Epoch 250:
# Train Loss: 4.457e-01, Val Loss: 4.423e-01
# Epoch 251:
# Train Loss: 4.616e-01, Val Loss: 4.588e-01
# Epoch 252:
# Train Loss: 4.569e-01, Val Loss: 4.489e-01
# Epoch 253:
# Train Loss: 4.556e-01, Val Loss: 4.480e-01
# Epoch 254:
# Train Loss: 4.617e-01, Val Loss: 4.433e-01
# Epoch 255:
# Train Loss: 4.589e-01, Val Loss: 4.769e-01
# Epoch 256:
# Train Loss: 4.591e-01, Val Loss: 4.902e-01
# Epoch 257:
# Train Loss: 4.706e-01, Val Loss: 4.821e-01
# Epoch 258:
# Train Loss: 4.707e-01, Val Loss: 4.533e-01
# Epoch 259:
# Train Loss: 4.735e-01, Val Loss: 5.287e-01
# Epoch 260:
# Train Loss: 4.569e-01, Val Loss: 5.116e-01
# Epoch 261:
# Train Loss: 4.554e-01, Val Loss: 4.720e-01
# Epoch 262:
# Train Loss: 4.521e-01, Val Loss: 4.536e-01
# Epoch 263:
# Train Loss: 4.789e-01, Val Loss: 4.731e-01
# Epoch 264:
# Train Loss: 4.538e-01, Val Loss: 4.288e-01
# Epoch 265:
# Train Loss: 4.764e-01, Val Loss: 4.775e-01
# Epoch 266:
# Train Loss: 4.782e-01, Val Loss: 4.984e-01
# Epoch 267:
# Train Loss: 4.683e-01, Val Loss: 4.642e-01
# Epoch 268:
# Train Loss: 4.740e-01, Val Loss: 4.570e-01
# Epoch 269:
# Train Loss: 4.535e-01, Val Loss: 4.686e-01
# Epoch 270:
# Train Loss: 4.751e-01, Val Loss: 4.659e-01
# Epoch 271:
# Train Loss: 4.492e-01, Val Loss: 4.645e-01
# Epoch 272:
# Train Loss: 4.654e-01, Val Loss: 4.400e-01
# Epoch 273:
# Train Loss: 4.593e-01, Val Loss: 4.286e-01
# Epoch 274:
# Train Loss: 4.739e-01, Val Loss: 4.679e-01
# Epoch 275:
# Train Loss: 4.610e-01, Val Loss: 3.907e-01
# Epoch 276:
# Train Loss: 4.575e-01, Val Loss: 4.397e-01
# Epoch 277:
# Train Loss: 4.555e-01, Val Loss: 4.128e-01
# Epoch 278:
# Train Loss: 4.513e-01, Val Loss: 4.640e-01
# Epoch 279:
# Train Loss: 4.586e-01, Val Loss: 4.268e-01
# Epoch 280:
# Train Loss: 4.588e-01, Val Loss: 4.979e-01
# Epoch 281:
# Train Loss: 4.709e-01, Val Loss: 4.802e-01
# Epoch 282:
# Train Loss: 4.483e-01, Val Loss: 4.672e-01
# Epoch 283:
# Train Loss: 4.889e-01, Val Loss: 4.378e-01
# Epoch 284:
# Train Loss: 4.673e-01, Val Loss: 4.698e-01
# Epoch 285:
# Train Loss: 4.668e-01, Val Loss: 4.688e-01
# Epoch 286:
# Train Loss: 4.526e-01, Val Loss: 4.657e-01
# Epoch 287:
# Train Loss: 4.569e-01, Val Loss: 4.237e-01
# Epoch 288:
# Train Loss: 4.508e-01, Val Loss: 4.922e-01
# Epoch 289:
# Train Loss: 4.760e-01, Val Loss: 4.167e-01
# Epoch 290:
# Train Loss: 4.775e-01, Val Loss: 4.441e-01
# Epoch 291:
# Train Loss: 4.639e-01, Val Loss: 4.699e-01
# Epoch 292:
# Train Loss: 4.824e-01, Val Loss: 4.558e-01
# Epoch 293:
# Train Loss: 4.710e-01, Val Loss: 4.814e-01
# Epoch 294:
# Train Loss: 4.675e-01, Val Loss: 5.274e-01
# Epoch 295:
# Train Loss: 4.638e-01, Val Loss: 4.580e-01
# Epoch 296:
# Train Loss: 4.556e-01, Val Loss: 4.557e-01
# Epoch 297:
# Train Loss: 4.479e-01, Val Loss: 4.470e-01
# Epoch 298:
# Train Loss: 4.503e-01, Val Loss: 4.680e-01
# Epoch 299:
# Train Loss: 4.538e-01, Val Loss: 5.315e-01
# Epoch 300:
# Train Loss: 4.696e-01, Val Loss: 4.456e-01
# Epoch 301:
# Train Loss: 4.615e-01, Val Loss: 4.152e-01
# Epoch 302:
# Train Loss: 4.579e-01, Val Loss: 4.880e-01
# Epoch 303:
# Train Loss: 4.587e-01, Val Loss: 4.763e-01
# Epoch 304:
# Train Loss: 4.462e-01, Val Loss: 4.644e-01
# Epoch 305:
# Train Loss: 4.623e-01, Val Loss: 4.238e-01
# Epoch 306:
# Train Loss: 4.609e-01, Val Loss: 4.544e-01
# Epoch 307:
# Train Loss: 4.527e-01, Val Loss: 5.190e-01
# Epoch 308:
# Train Loss: 4.571e-01, Val Loss: 4.652e-01
# Epoch 309:
# Train Loss: 4.801e-01, Val Loss: 4.078e-01
# Epoch 310:
# Train Loss: 4.599e-01, Val Loss: 4.445e-01
# Epoch 311:
# Train Loss: 4.718e-01, Val Loss: 4.980e-01
# Epoch 312:
# Train Loss: 4.469e-01, Val Loss: 4.254e-01
# Epoch 313:
# Train Loss: 4.758e-01, Val Loss: 4.663e-01
# Epoch 314:
# Train Loss: 4.715e-01, Val Loss: 4.318e-01
# Epoch 315:
# Train Loss: 4.486e-01, Val Loss: 4.345e-01
# Epoch 316:
# Train Loss: 4.615e-01, Val Loss: 3.696e-01
# Epoch 317:
# Train Loss: 4.514e-01, Val Loss: 4.195e-01
# Epoch 318:
# Train Loss: 4.755e-01, Val Loss: 4.393e-01
# Epoch 319:
# Train Loss: 4.853e-01, Val Loss: 4.415e-01
# Epoch 320:
# Train Loss: 4.639e-01, Val Loss: 4.328e-01
# Epoch 321:
# Train Loss: 4.668e-01, Val Loss: 4.747e-01
# Epoch 322:
# Train Loss: 4.625e-01, Val Loss: 4.369e-01
# Epoch 323:
# Train Loss: 4.669e-01, Val Loss: 4.299e-01
# Epoch 324:
# Train Loss: 4.872e-01, Val Loss: 4.947e-01
# Epoch 325:
# Train Loss: 4.749e-01, Val Loss: 4.760e-01
# Epoch 326:
# Train Loss: 4.791e-01, Val Loss: 4.351e-01
# Epoch 327:
# Train Loss: 4.417e-01, Val Loss: 4.532e-01
# Epoch 328:
# Train Loss: 4.762e-01, Val Loss: 4.739e-01
# Epoch 329:
# Train Loss: 4.466e-01, Val Loss: 4.416e-01
# Epoch 330:
# Train Loss: 4.722e-01, Val Loss: 4.811e-01
# Epoch 331:
# Train Loss: 4.527e-01, Val Loss: 4.380e-01
# Epoch 332:
# Train Loss: 4.776e-01, Val Loss: 4.260e-01
# Epoch 333:
# Train Loss: 4.828e-01, Val Loss: 4.505e-01
# Epoch 334:
# Train Loss: 4.587e-01, Val Loss: 4.629e-01
# Epoch 335:
# Train Loss: 4.679e-01, Val Loss: 4.172e-01
# Epoch 336:
# Train Loss: 4.890e-01, Val Loss: 4.343e-01
# Epoch 337:
# Train Loss: 4.604e-01, Val Loss: 4.433e-01
# Epoch 338:
# Train Loss: 4.677e-01, Val Loss: 4.705e-01
# Epoch 339:
# Train Loss: 4.720e-01, Val Loss: 4.597e-01
# Epoch 340:
# Train Loss: 4.625e-01, Val Loss: 4.224e-01
# Epoch 341:
# Train Loss: 4.772e-01, Val Loss: 4.894e-01
# Epoch 342:
# Train Loss: 4.729e-01, Val Loss: 4.705e-01
# Epoch 343:
# Train Loss: 4.558e-01, Val Loss: 4.791e-01
# Epoch 344:
# Train Loss: 4.536e-01, Val Loss: 4.386e-01
# Epoch 345:
# Train Loss: 4.640e-01, Val Loss: 4.404e-01
# Epoch 346:
# Train Loss: 4.554e-01, Val Loss: 4.341e-01
# Epoch 347:
# Train Loss: 4.590e-01, Val Loss: 4.684e-01
# Epoch 348:
# Train Loss: 4.664e-01, Val Loss: 5.047e-01
# Epoch 349:
# Train Loss: 4.704e-01, Val Loss: 4.753e-01
# Epoch 350:
# Train Loss: 4.756e-01, Val Loss: 5.099e-01
# Epoch 351:
# Train Loss: 4.793e-01, Val Loss: 4.417e-01
# Epoch 352:
# Train Loss: 4.493e-01, Val Loss: 4.772e-01
# Epoch 353:
# Train Loss: 4.465e-01, Val Loss: 4.835e-01
# Epoch 354:
# Train Loss: 4.852e-01, Val Loss: 5.098e-01
# Epoch 355:
# Train Loss: 4.651e-01, Val Loss: 4.987e-01
# Epoch 356:
# Train Loss: 4.528e-01, Val Loss: 4.058e-01
# Epoch 357:
# Train Loss: 4.423e-01, Val Loss: 4.735e-01
# Epoch 358:
# Train Loss: 4.476e-01, Val Loss: 4.967e-01
# Epoch 359:
# Train Loss: 4.575e-01, Val Loss: 4.443e-01
# Epoch 360:
# Train Loss: 4.931e-01, Val Loss: 4.674e-01
# Epoch 361:
# Train Loss: 4.404e-01, Val Loss: 4.665e-01
# Epoch 362:
# Train Loss: 4.668e-01, Val Loss: 4.508e-01
# Epoch 363:
# Train Loss: 4.646e-01, Val Loss: 4.372e-01
# Epoch 364:
# Train Loss: 4.484e-01, Val Loss: 4.549e-01
# Epoch 365:
# Train Loss: 4.599e-01, Val Loss: 5.284e-01
# Epoch 366:
# Train Loss: 4.693e-01, Val Loss: 4.227e-01
# Epoch 367:
# Train Loss: 4.608e-01, Val Loss: 4.498e-01
# Epoch 368:
# Train Loss: 4.709e-01, Val Loss: 3.948e-01
# Epoch 369:
# Train Loss: 4.718e-01, Val Loss: 4.434e-01
# Epoch 370:
# Train Loss: 4.639e-01, Val Loss: 4.405e-01
# Epoch 371:
# Train Loss: 4.639e-01, Val Loss: 4.517e-01
# Epoch 372:
# Train Loss: 4.465e-01, Val Loss: 5.007e-01
# Epoch 373:
# Train Loss: 4.554e-01, Val Loss: 5.368e-01
# Epoch 374:
# Train Loss: 4.785e-01, Val Loss: 4.219e-01
# Epoch 375:
# Train Loss: 4.624e-01, Val Loss: 4.843e-01
# Epoch 376:
# Train Loss: 4.528e-01, Val Loss: 4.647e-01
# Epoch 377:
# Train Loss: 4.516e-01, Val Loss: 4.906e-01
# Epoch 378:
# Train Loss: 4.612e-01, Val Loss: 5.101e-01
# Epoch 379:
# Train Loss: 4.322e-01, Val Loss: 4.429e-01
# Epoch 380:
# Train Loss: 4.551e-01, Val Loss: 4.884e-01
# Epoch 381:
# Train Loss: 4.691e-01, Val Loss: 4.898e-01
# Epoch 382:
# Train Loss: 4.557e-01, Val Loss: 4.815e-01
# Epoch 383:
# Train Loss: 4.857e-01, Val Loss: 4.439e-01
# Epoch 384:
# Train Loss: 4.652e-01, Val Loss: 4.514e-01
# Epoch 385:
# Train Loss: 4.488e-01, Val Loss: 4.598e-01
# Epoch 386:
# Train Loss: 4.536e-01, Val Loss: 5.114e-01
# Epoch 387:
# Train Loss: 4.727e-01, Val Loss: 4.905e-01
# Epoch 388:
# Train Loss: 4.671e-01, Val Loss: 4.740e-01
# Epoch 389:
# Train Loss: 4.593e-01, Val Loss: 4.845e-01
# Epoch 390:
# Train Loss: 4.723e-01, Val Loss: 5.087e-01
# Epoch 391:
# Train Loss: 4.725e-01, Val Loss: 5.249e-01
# Epoch 392:
# Train Loss: 4.757e-01, Val Loss: 4.880e-01
# Epoch 393:
# Train Loss: 4.791e-01, Val Loss: 4.609e-01
# Epoch 394:
# Train Loss: 4.768e-01, Val Loss: 5.203e-01
# Epoch 395:
# Train Loss: 4.506e-01, Val Loss: 4.103e-01
# Epoch 396:
# Train Loss: 4.566e-01, Val Loss: 4.532e-01
# Epoch 397:
# Train Loss: 4.652e-01, Val Loss: 4.353e-01
# Epoch 398:
# Train Loss: 4.618e-01, Val Loss: 4.900e-01
# Epoch 399:
# Train Loss: 4.652e-01, Val Loss: 4.898e-01
# Epoch 400:
# Train Loss: 4.554e-01, Val Loss: 4.644e-01
# Epoch 401:
# Train Loss: 4.654e-01, Val Loss: 4.712e-01
# Epoch 402:
# Train Loss: 4.603e-01, Val Loss: 4.808e-01
# Epoch 403:
# Train Loss: 4.530e-01, Val Loss: 4.808e-01
# Epoch 404:
# Train Loss: 4.628e-01, Val Loss: 5.097e-01
# Epoch 405:
# Train Loss: 4.750e-01, Val Loss: 4.823e-01
# Epoch 406:
# Train Loss: 4.600e-01, Val Loss: 4.677e-01
# Epoch 407:
# Train Loss: 4.458e-01, Val Loss: 4.583e-01
# Epoch 408:
# Train Loss: 4.677e-01, Val Loss: 4.088e-01
# Epoch 409:
# Train Loss: 4.692e-01, Val Loss: 4.929e-01
# Epoch 410:
# Train Loss: 4.598e-01, Val Loss: 4.541e-01
# Epoch 411:
# Train Loss: 4.528e-01, Val Loss: 4.518e-01
# Epoch 412:
# Train Loss: 4.660e-01, Val Loss: 4.475e-01
# Epoch 413:
# Train Loss: 4.470e-01, Val Loss: 4.739e-01
# Epoch 414:
# Train Loss: 4.576e-01, Val Loss: 4.601e-01
# Epoch 415:
# Train Loss: 4.760e-01, Val Loss: 4.799e-01
# Epoch 416:
# Train Loss: 4.470e-01, Val Loss: 4.341e-01
# Epoch 417:
# Train Loss: 4.635e-01, Val Loss: 4.201e-01
# Epoch 418:
# Train Loss: 4.605e-01, Val Loss: 4.701e-01
# Epoch 419:
# Train Loss: 4.780e-01, Val Loss: 5.102e-01
# Epoch 420:
# Train Loss: 4.539e-01, Val Loss: 3.821e-01
# Epoch 421:
# Train Loss: 4.606e-01, Val Loss: 4.242e-01
# Epoch 422:
# Train Loss: 4.765e-01, Val Loss: 4.655e-01
# Epoch 423:
# Train Loss: 4.757e-01, Val Loss: 5.148e-01
# Epoch 424:
# Train Loss: 4.909e-01, Val Loss: 4.661e-01
# Epoch 425:
# Train Loss: 4.737e-01, Val Loss: 3.974e-01
# Epoch 426:
# Train Loss: 4.610e-01, Val Loss: 4.144e-01
# Epoch 427:
# Train Loss: 4.549e-01, Val Loss: 4.436e-01
# Epoch 428:
# Train Loss: 4.888e-01, Val Loss: 4.693e-01
# Epoch 429:
# Train Loss: 4.420e-01, Val Loss: 4.306e-01
# Epoch 430:
# Train Loss: 4.464e-01, Val Loss: 4.424e-01
# Epoch 431:
# Train Loss: 4.800e-01, Val Loss: 4.564e-01
# Epoch 432:
# Train Loss: 4.584e-01, Val Loss: 4.403e-01
# Epoch 433:
# Train Loss: 4.552e-01, Val Loss: 4.478e-01
# Epoch 434:
# Train Loss: 4.636e-01, Val Loss: 5.035e-01
# Epoch 435:
# Train Loss: 4.638e-01, Val Loss: 4.956e-01
# Epoch 436:
# Train Loss: 4.613e-01, Val Loss: 3.759e-01
# Epoch 437:
# Train Loss: 4.793e-01, Val Loss: 4.875e-01
# Epoch 438:
# Train Loss: 4.652e-01, Val Loss: 4.111e-01
# Epoch 439:
# Train Loss: 4.762e-01, Val Loss: 5.050e-01
# Epoch 440:
# Train Loss: 4.608e-01, Val Loss: 4.361e-01
# Epoch 441:
# Train Loss: 4.606e-01, Val Loss: 3.947e-01
# Epoch 442:
# Train Loss: 4.705e-01, Val Loss: 4.541e-01
# Epoch 443:
# Train Loss: 4.613e-01, Val Loss: 4.301e-01
# Epoch 444:
# Train Loss: 4.537e-01, Val Loss: 4.858e-01
# Epoch 445:
# Train Loss: 4.510e-01, Val Loss: 4.855e-01
# Epoch 446:
# Train Loss: 4.613e-01, Val Loss: 4.111e-01
# Epoch 447:
# Train Loss: 4.474e-01, Val Loss: 5.071e-01
# Epoch 448:
# Train Loss: 4.468e-01, Val Loss: 5.152e-01
# Epoch 449:
# Train Loss: 4.763e-01, Val Loss: 4.293e-01
# Epoch 450:
# Train Loss: 4.449e-01, Val Loss: 5.096e-01
# Epoch 451:
# Train Loss: 4.653e-01, Val Loss: 4.437e-01
# Epoch 452:
# Train Loss: 4.482e-01, Val Loss: 4.536e-01
# Epoch 453:
# Train Loss: 4.518e-01, Val Loss: 4.034e-01
# Epoch 454:
# Train Loss: 4.686e-01, Val Loss: 4.869e-01
# Epoch 455:
# Train Loss: 4.637e-01, Val Loss: 4.635e-01
# Epoch 456:
# Train Loss: 4.567e-01, Val Loss: 4.391e-01
# Epoch 457:
# Train Loss: 4.586e-01, Val Loss: 4.445e-01
# Epoch 458:
# Train Loss: 4.666e-01, Val Loss: 4.803e-01
# Epoch 459:
# Train Loss: 4.691e-01, Val Loss: 5.276e-01
# Epoch 460:
# Train Loss: 4.558e-01, Val Loss: 4.165e-01
# Epoch 461:
# Train Loss: 4.678e-01, Val Loss: 5.033e-01
# Epoch 462:
# Train Loss: 4.376e-01, Val Loss: 4.606e-01
# Epoch 463:
# Train Loss: 4.626e-01, Val Loss: 4.354e-01
# Epoch 464:
# Train Loss: 4.667e-01, Val Loss: 4.541e-01
# Epoch 465:
# Train Loss: 4.710e-01, Val Loss: 4.589e-01
# Epoch 466:
# Train Loss: 4.765e-01, Val Loss: 5.416e-01
# Epoch 467:
# Train Loss: 4.887e-01, Val Loss: 4.452e-01
# Epoch 468:
# Train Loss: 4.736e-01, Val Loss: 4.529e-01
# Epoch 469:
# Train Loss: 4.730e-01, Val Loss: 4.852e-01
# Epoch 470:
# Train Loss: 4.738e-01, Val Loss: 4.469e-01
# Epoch 471:
# Train Loss: 4.710e-01, Val Loss: 4.161e-01
# Epoch 472:
# Train Loss: 4.770e-01, Val Loss: 4.675e-01
# Epoch 473:
# Train Loss: 4.696e-01, Val Loss: 4.866e-01
# Epoch 474:
# Train Loss: 4.778e-01, Val Loss: 5.244e-01
# Epoch 475:
# Train Loss: 4.591e-01, Val Loss: 4.209e-01
# Epoch 476:
# Train Loss: 4.673e-01, Val Loss: 4.449e-01
# Epoch 477:
# Train Loss: 4.511e-01, Val Loss: 4.411e-01
# Epoch 478:
# Train Loss: 4.529e-01, Val Loss: 4.146e-01
# Epoch 479:
# Train Loss: 4.445e-01, Val Loss: 4.398e-01
# Epoch 480:
# Train Loss: 4.731e-01, Val Loss: 4.628e-01
# Epoch 481:
# Train Loss: 4.646e-01, Val Loss: 4.361e-01
# Epoch 482:
# Train Loss: 4.646e-01, Val Loss: 4.495e-01
# Epoch 483:
# Train Loss: 4.791e-01, Val Loss: 4.489e-01
# Epoch 484:
# Train Loss: 4.599e-01, Val Loss: 5.209e-01
# Epoch 485:
# Train Loss: 4.723e-01, Val Loss: 5.105e-01
# Epoch 486:
# Train Loss: 4.647e-01, Val Loss: 4.981e-01
# Epoch 487:
# Train Loss: 4.502e-01, Val Loss: 4.413e-01
# Epoch 488:
# Train Loss: 4.570e-01, Val Loss: 4.502e-01
# Epoch 489:
# Train Loss: 4.548e-01, Val Loss: 4.699e-01
# Epoch 490:
# Train Loss: 4.655e-01, Val Loss: 4.014e-01
# Epoch 491:
# Train Loss: 4.696e-01, Val Loss: 4.736e-01
# Epoch 492:
# Train Loss: 4.567e-01, Val Loss: 4.727e-01
# Epoch 493:
# Train Loss: 4.697e-01, Val Loss: 4.572e-01
# Epoch 494:
# Train Loss: 4.812e-01, Val Loss: 4.803e-01
# Epoch 495:
# Train Loss: 4.643e-01, Val Loss: 4.966e-01
# Epoch 496:
# Train Loss: 4.731e-01, Val Loss: 4.989e-01
# Epoch 497:
# Train Loss: 4.542e-01, Val Loss: 4.748e-01
# Epoch 498:
# Train Loss: 4.535e-01, Val Loss: 4.340e-01
# Epoch 499:
# Train Loss: 4.568e-01, Val Loss: 4.416e-01
# Epoch 500:
# Train Loss: 4.651e-01, Val Loss: 4.418e-01
# Epoch 501:
# Train Loss: 4.842e-01, Val Loss: 4.561e-01
# Epoch 502:
# Train Loss: 4.645e-01, Val Loss: 4.340e-01
# Epoch 503:
# Train Loss: 4.861e-01, Val Loss: 4.441e-01
# Epoch 504:
# Train Loss: 4.665e-01, Val Loss: 4.390e-01
# Epoch 505:
# Train Loss: 4.701e-01, Val Loss: 5.245e-01
# Epoch 506:
# Train Loss: 4.510e-01, Val Loss: 4.522e-01
# Epoch 507:
# Train Loss: 4.615e-01, Val Loss: 4.208e-01
# Epoch 508:
# Train Loss: 4.645e-01, Val Loss: 4.593e-01
# Epoch 509:
# Train Loss: 4.725e-01, Val Loss: 4.480e-01
# Epoch 510:
# Train Loss: 4.693e-01, Val Loss: 4.597e-01
# Epoch 511:
# Train Loss: 4.572e-01, Val Loss: 4.144e-01
# Epoch 512:
# Train Loss: 4.526e-01, Val Loss: 5.439e-01
# Epoch 513:
# Train Loss: 4.570e-01, Val Loss: 4.864e-01
# Epoch 514:
# Train Loss: 4.770e-01, Val Loss: 4.589e-01
# Epoch 515:
# Train Loss: 4.591e-01, Val Loss: 4.390e-01
# Epoch 516:
# Train Loss: 4.652e-01, Val Loss: 4.964e-01
# Epoch 517:
# Train Loss: 4.745e-01, Val Loss: 3.894e-01
# Epoch 518:
# Train Loss: 4.689e-01, Val Loss: 4.408e-01
# Epoch 519:
# Train Loss: 4.581e-01, Val Loss: 4.483e-01
# Epoch 520:
# Train Loss: 4.663e-01, Val Loss: 5.097e-01
# Epoch 521:
# Train Loss: 4.502e-01, Val Loss: 4.658e-01
# Epoch 522:
# Train Loss: 4.690e-01, Val Loss: 4.734e-01
# Epoch 523:
# Train Loss: 4.526e-01, Val Loss: 4.846e-01
# Epoch 524:
# Train Loss: 4.626e-01, Val Loss: 4.969e-01
# Epoch 525:
# Train Loss: 4.551e-01, Val Loss: 4.529e-01
# Epoch 526:
# Train Loss: 4.814e-01, Val Loss: 4.244e-01
# Epoch 527:
# Train Loss: 4.608e-01, Val Loss: 4.937e-01
# Epoch 528:
# Train Loss: 4.740e-01, Val Loss: 4.813e-01
# Epoch 529:
# Train Loss: 4.909e-01, Val Loss: 5.002e-01
# Epoch 530:
# Train Loss: 4.613e-01, Val Loss: 4.705e-01
# Epoch 531:
# Train Loss: 4.304e-01, Val Loss: 4.806e-01
# Epoch 532:
# Train Loss: 4.574e-01, Val Loss: 4.309e-01
# Epoch 533:
# Train Loss: 4.643e-01, Val Loss: 4.301e-01
# Epoch 534:
# Train Loss: 4.636e-01, Val Loss: 4.498e-01
# Epoch 535:
# Train Loss: 4.913e-01, Val Loss: 4.370e-01
# Epoch 536:
# Train Loss: 4.682e-01, Val Loss: 4.573e-01
# Epoch 537:
# Train Loss: 4.800e-01, Val Loss: 4.659e-01
# Epoch 538:
# Train Loss: 4.425e-01, Val Loss: 4.470e-01
# Epoch 539:
# Train Loss: 4.739e-01, Val Loss: 4.799e-01
# Epoch 540:
# Train Loss: 4.475e-01, Val Loss: 5.196e-01
# Epoch 541:
# Train Loss: 4.585e-01, Val Loss: 4.836e-01
# Epoch 542:
# Train Loss: 4.619e-01, Val Loss: 4.600e-01
# Epoch 543:
# Train Loss: 4.594e-01, Val Loss: 4.486e-01
# Epoch 544:
# Train Loss: 4.660e-01, Val Loss: 4.762e-01
# Epoch 545:
# Train Loss: 4.657e-01, Val Loss: 5.101e-01
# Epoch 546:
# Train Loss: 4.560e-01, Val Loss: 4.379e-01
# Epoch 547:
# Train Loss: 4.618e-01, Val Loss: 4.394e-01
# Epoch 548:
# Train Loss: 4.522e-01, Val Loss: 5.283e-01
# Epoch 549:
# Train Loss: 4.354e-01, Val Loss: 4.692e-01
# Epoch 550:
# Train Loss: 4.600e-01, Val Loss: 4.848e-01
# Epoch 551:
# Train Loss: 4.769e-01, Val Loss: 4.578e-01
# Epoch 552:
# Train Loss: 4.505e-01, Val Loss: 5.024e-01
# Epoch 553:
# Train Loss: 4.536e-01, Val Loss: 4.252e-01
# Epoch 554:
# Train Loss: 4.557e-01, Val Loss: 5.044e-01
# Epoch 555:
# Train Loss: 4.768e-01, Val Loss: 4.605e-01
# Epoch 556:
# Train Loss: 4.567e-01, Val Loss: 4.775e-01
# Epoch 557:
# Train Loss: 4.667e-01, Val Loss: 4.798e-01
# Epoch 558:
# Train Loss: 4.631e-01, Val Loss: 4.651e-01
# Epoch 559:
# Train Loss: 4.655e-01, Val Loss: 4.749e-01
# Epoch 560:
# Train Loss: 4.722e-01, Val Loss: 4.527e-01
# Epoch 561:
# Train Loss: 4.531e-01, Val Loss: 4.583e-01
# Epoch 562:
# Train Loss: 4.735e-01, Val Loss: 4.832e-01
# Epoch 563:
# Train Loss: 4.723e-01, Val Loss: 4.920e-01
# Epoch 564:
# Train Loss: 4.728e-01, Val Loss: 4.063e-01
# Epoch 565:
# Train Loss: 4.627e-01, Val Loss: 4.973e-01
# Epoch 566:
# Train Loss: 4.535e-01, Val Loss: 4.425e-01
# Epoch 567:
# Train Loss: 4.867e-01, Val Loss: 4.701e-01
# Epoch 568:
# Train Loss: 4.668e-01, Val Loss: 4.934e-01
# Epoch 569:
# Train Loss: 4.684e-01, Val Loss: 4.395e-01
# Epoch 570:
# Train Loss: 4.594e-01, Val Loss: 4.630e-01
# Epoch 571:
# Train Loss: 4.695e-01, Val Loss: 4.573e-01
# Epoch 572:
# Train Loss: 4.437e-01, Val Loss: 4.756e-01
# Epoch 573:
# Train Loss: 4.695e-01, Val Loss: 4.604e-01
# Epoch 574:
# Train Loss: 4.554e-01, Val Loss: 4.647e-01
# Epoch 575:
# Train Loss: 4.541e-01, Val Loss: 4.115e-01
# Epoch 576:
# Train Loss: 4.765e-01, Val Loss: 4.872e-01
# Epoch 577:
# Train Loss: 4.739e-01, Val Loss: 4.828e-01
# Epoch 578:
# Train Loss: 4.795e-01, Val Loss: 3.914e-01
# Epoch 579:
# Train Loss: 4.702e-01, Val Loss: 4.914e-01
# Epoch 580:
# Train Loss: 4.675e-01, Val Loss: 4.854e-01
# Epoch 581:
# Train Loss: 4.290e-01, Val Loss: 4.095e-01
# Epoch 582:
# Train Loss: 4.762e-01, Val Loss: 4.711e-01
# Epoch 583:
# Train Loss: 4.638e-01, Val Loss: 4.782e-01
# Epoch 584:
# Train Loss: 4.643e-01, Val Loss: 4.394e-01
# Epoch 585:
# Train Loss: 4.739e-01, Val Loss: 4.583e-01
# Epoch 586:
# Train Loss: 4.566e-01, Val Loss: 5.285e-01
# Epoch 587:
# Train Loss: 4.738e-01, Val Loss: 4.468e-01
# Epoch 588:
# Train Loss: 4.475e-01, Val Loss: 4.694e-01
# Epoch 589:
# Train Loss: 4.613e-01, Val Loss: 4.192e-01
# Epoch 590:
# Train Loss: 4.613e-01, Val Loss: 4.347e-01
# Epoch 591:
# Train Loss: 4.696e-01, Val Loss: 4.864e-01
# Epoch 592:
# Train Loss: 4.731e-01, Val Loss: 4.393e-01
# Epoch 593:
# Train Loss: 4.611e-01, Val Loss: 4.863e-01
# Epoch 594:
# Train Loss: 4.695e-01, Val Loss: 4.609e-01
# Epoch 595:
# Train Loss: 4.806e-01, Val Loss: 4.887e-01
# Epoch 596:
# Train Loss: 4.571e-01, Val Loss: 4.754e-01
# Epoch 597:
# Train Loss: 4.621e-01, Val Loss: 4.510e-01
# Epoch 598:
# Train Loss: 4.575e-01, Val Loss: 4.321e-01
# Epoch 599:
# Train Loss: 4.555e-01, Val Loss: 4.285e-01
# Epoch 600:
# Train Loss: 4.679e-01, Val Loss: 4.482e-01

# %%
# History
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(range(num_epochs), train_loss_hist)
ax[1].plot(range(num_epochs), val_loss_hist)
ax[0].set_title('Train Loss')
ax[1].set_title('Val Loss')
for axs in ax:
    axs.set_yscale('log')

# %% [markdown]
# ### 4. Assessment

# %% [markdown]
# #### 4.1 Accuracy of learned dynamics
#
# To begin with, we assess the accuracy of the learned dynamics. For that, we compare the predicted and true population change rates induced by the natural dynamics, as a function of the population size.

# %%
p = solution.y[0]

# True relationship
ground_truth = r*p*(1-p/k)

pred = ode_nn.predict(p, batch_size=128)

'''
# Predicted relationship
with tf.device("CPU:0"):
    pred = ode_nn.predict(p, batch_size=128)
'''
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# '\n# Predicted relationship\nwith tf.device("CPU:0"):\n    pred = ode_nn.predict(p, batch_size=128)\n'

# %%
fig, ax = plt.subplots()
ax.plot(p, ground_truth, label='Ground Truth')
ax.plot(p, pred[1].flatten(), label='Predict')
ax.set_xlabel("Population Size", fontsize=16)
ax.set_ylabel("Population Change Rate", fontsize=16)
ax.legend();

# %% [markdown]
# #### 4.2 Long-term forecasting

# %% [markdown]
# Next, we test if the trained Neural ODE model can perform long-term integration given the initial population size used in training. Note that unlike the training phase, here, we **only** supply the trained model with the initial population size. The model will autoregressively predict the entire population evolution.
#
# First, let's define a helper function to make predictions with Neural ODE model.

# %%
@tf.function
def neuralODE_pred(p_init, t, ode_nn, h, H_max):
    """
    Using trained neural ODE to autogressively predict the population evolution.

    inputs:
    -------
    p_init: initial population size
    t: array of timestamps
    ode_nn: trained neural ODE model
    h: harvesting rate
    H_max: maximum harvesting capacity

    Outputs:
    --------
    preds: array of population evolution
    """

    preds = tf.TensorArray(dtype=tf.float32, size=tf.size(t))
    preds = preds.write(0, p_init)
    p = tf.constant([[p_init]], dtype=tf.float32)

    # Loop over time steps
    for i in tf.range(tf.size(t)-1):

        # Calculate time interval
        delta_t = t[i+1]-t[i]

        # Calculate population change rate
        _, natural_dynamics = ode_nn(p)
        dp_dt = natural_dynamics - tf.minimum(h*p, H_max)

        # Euler integration scheme
        p = p + delta_t*dp_dt

        # Store prediction
        preds = preds.write(i+1, p[0][0])

    return preds.stack()

# %% [markdown]
# Next, we simulate the population growth using the same setting employed during model training.

# %%
# Set parameters
r, k, h, H_max = 0.1, 1000, 0.01, 5

# Initial condition
p_0 = 20

# Simulation time span
t_span = (0, 100)
t_eval = np.linspace(t_span[0], t_span[1], 1000)

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0],
                     t_eval=t_eval, args=(r, k, h, H_max))

# %%
# Neural ODE predictions
t_eval = t_eval.astype(np.float32)
predictions = neuralODE_pred(p_0, t_eval, ode_nn, h, H_max)

# %%
fig, ax = plt.subplots()
ax.plot(t_eval, solution.y[0], label='Truth')
ax.plot(t_eval, predictions, label='Predict')
ax.set_xlabel("Time (days)", fontsize=16)
ax.set_ylabel("Population Size", fontsize=16)
ax.legend();

# %% [markdown]
# #### 4.3 Dynamical modeling with different settings
#
# Finally, we test if the trained Neural ODE model can predict the population growth given a different set of initial condition and harvesting setting. Specifically, we set the new initial population as $p_0=60$, and the harvesting parameters $h=0.05$, $H_{max} = 40$.

# %% [markdown]
# We first simulate the population growth under the new setting.

# %%
# Set new harvesting parameters
h_new, H_max_new = 0.05, 40

# Initial condition
p_0_new = 60

# Simulation time span
t_span = (0, 100)
t_eval = np.linspace(t_span[0], t_span[1], 1000)

# Solve ODE
solution = solve_ivp(logistic_growth, t_span, [p_0_new],
                     t_eval=t_eval, args=(r, k, h_new, H_max_new))

# %% [markdown]
# Afterward, we use the trained Neural ODE to predict the population growth.

# %%
# Neural ODE predictions
t_eval = t_eval.astype(np.float32)
predictions = neuralODE_pred(p_0_new, t_eval, ode_nn, h_new, H_max_new)

# %%
fig, ax = plt.subplots()
ax.plot(t_eval, solution.y[0], label='Truth')
ax.plot(t_eval, predictions, label='Predict')
ax.set_xlabel("Time (days)", fontsize=16)
ax.set_ylabel("Population Size", fontsize=16)
ax.legend();
